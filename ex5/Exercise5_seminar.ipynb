# %%
import sys
import xarray as xr
import os
import matplotlib.pyplot as plt
import numpy as np
from scipy.linalg import det, inv, eig

# %%
from jupyterthemes import jtplot
# currently installed theme will be used to
# set plot style if no arguments provided
jtplot.style()
jtplot.style(theme='chesterish')

# %% [markdown]
# # Exercise 5
#
# ## Part I
#
# Generate different AR(m) processes and estimate their parameters $\alpha$ using two different methods:
# (i)  By using the least squares approach (see Eq. 2.2.98).
# (ii)  By using the ARIMA function from the library statsmodels.
# Compare the results also with respect to the parameter AIC given by the ARIMA function.
#
# Tipps:
# For generating an AR(m) process and for calculating the autocovariance function you can also use functions from the library statsmodels:
# https://www.statsmodels.org/stable/generated/statsmodels.tsa.arima_process.arma_generate_sample.html
# https://www.statsmodels.org/stable/generated/statsmodels.tsa.stattools.acovf.html
# https://www.statsmodels.org/stable/generated/statsmodels.tsa.arima.model.ARIMA.html
#
# Information about what AIC is you can find for example here:
# https://towardsdatascience.com/the-akaike-information-criterion-c20c8fd832f2

# %% [markdown]
# ## Part II (Homework)

# %% [markdown]
# Estimate the AR(m) Process of the temperature timeseries from Hamburg-Fuhlsbuettel:
# (i) Calculate the residuals by substracting annual cycle and trend.
# (ii) Apply the ARIMA function for $m\in{1,2,...,5}$ on the residuals. For which m the AR(m) fits the best?
# (iii)  Give the parameters $\alpha$ of the AR(m) process as well as the estimated standard deviation $\sigma$ of the best fitting process.

# %%
# !pwd
# Out:
# /home/igor/UNI/KLIMDYN/KLIMDYN2/Hometasks/ex5

# %%
fname='/home/igor/UNI/KLIMDYN/KLIMDYN2/Hometasks/ex1/tHAMBURG-FUHLS.nc'
ds = xr.open_dataset(fname,decode_times=False)

# %%
df=ds.to_dataframe()
df
# Out:
#         temp
# time
# 8412.0   1.1
# 8413.0   1.4
# 8414.0   1.9
# 8415.0   7.0
# 8416.0  10.9
# ...      ...
# 8899.0  17.1
# 8900.0  14.7
# 8901.0   9.3
# 8902.0   4.9
# 8903.0   2.6
#
# [492 rows x 1 columns]

# %%
time=np.arange(len(ds.time))

# %%
fig= plt.figure(figsize=(19,10))
plt.plot(time,ds.temp,"-o")
