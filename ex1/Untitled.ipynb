# %%
import sys
import xarray as xr
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
# !pwd
# Out:
# /home/igor/UNI/KLIMDYN/KLIMDYN2/Hometasks/ex1

# %%
# !ls
# Out:
# tHAMBURG-FUHLS.nc  Untitled.ipynb

# %%
fname='tHAMBURG-FUHLS.nc'
ds = xr.open_dataset(fname,decode_times=False)

# %%
ds.temp
# Out:
# <xarray.DataArray 'temp' (time: 492)>
# array([1.1, 1.4, 1.9, ..., 9.3, 4.9, 2.6], dtype=float32)
# Coordinates:
#   * time     (time) float32 8412.0 8413.0 8414.0 8415.0 ... 8901.0 8902.0 8903.0
# Attributes:
#     long_name:  HAMBURG-FUHLS

# %%
ds.time
# Out:
# <xarray.DataArray 'time' (time: 492)>
# array([8412., 8413., 8414., ..., 8901., 8902., 8903.], dtype=float32)
# Coordinates:
#   * time     (time) float32 8412.0 8413.0 8414.0 8415.0 ... 8901.0 8902.0 8903.0
# Attributes:
#     units:    months since 1250-01-15

# %%
plt.plot(ds.time,ds.temp)

# %%
time=np.arange(len(ds.time))

# %%
fig= plt.figure(figsize=(19,10))
plt.plot(time,ds.temp,"-o")

# %%
from scipy.fft import fft

# %%
 y= fft(ds.temp.values)

# %%
plt.plot(y.real)

# %%
PI=np.pi
y=[np.sin(2*PI*x) for x in range(10)]

# %%
y
# Out:
# [0.0,
#  -2.4492935982947064e-16,
#  -4.898587196589413e-16,
#  -7.347880794884119e-16,
#  -9.797174393178826e-16,
#  -1.2246467991473533e-15,
#  -1.4695761589768238e-15,
#  -1.7145055188062944e-15,
#  -1.959434878635765e-15,
#  -2.204364238465236e-15]

# %%
plt.plot(y)

# %%
f= fft(y)
plt.plot(f)
# Out:
# /srv/conda3/envs/py3-general/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
